# %% [markdown]
# <a href="https://colab.research.google.com/github/zangdev/ml_crypto_ml/blob/main/ml_crypto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.neural_network import MLPRegressor
import requests
import time
import os
import joblib


def append_to_file(file_name, content):
    timestamp = pd.Timestamp.now()
    with open(file_name, 'a') as file:
        file.write(f"{timestamp} - {content}\n")


# Function to fetch real-time Bitcoin data from CoinGecko API
def get_bitcoin_data():
    try:
        url = "https://bitcoinaverage-global-bitcoin-index-v1.p.rapidapi.com/indices/global/ticker/BTCUSD"
        headers = {
            "X-RapidAPI-Key": "b204f4c757msh7af6d9244ca8807p166086jsne81ed71fea4a",
            "X-RapidAPI-Host": "bitcoinaverage-global-bitcoin-index-v1.p.rapidapi.com"
        }
        response = requests.get(url, headers=headers)
        data = response.json()
        return process_bitcoin_data(data)
    except Exception as e:
        print("Error fetching Bitcoin data:", e)
        return None


def process_bitcoin_data(data):
    bitcoin_price = data['last']
    bitcoin_high = data['high']
    bitcoin_low = data['low']
    bitcoin_volume = data['volume']
    bitcoin_open_hour = data['open']['hour']
    bitcoin_open_day = data['open']['day']
    bitcoin_open_week = data['open']['week']
    bitcoin_open_month = data['open']['month']
    bitcoin_open_month_3 = data['open']['month_3']
    bitcoin_open_month_6 = data['open']['month_6']
    bitcoin_open_year = data['open']['year']
    bitcoin_changes_hour = data['changes']['price']['hour']
    bitcoin_changes_day = data['changes']['price']['day']
    bitcoin_changes_week = data['changes']['price']['week']
    bitcoin_changes_month = data['changes']['price']['month']
    bitcoin_changes_month_3 = data['changes']['price']['month_3']
    bitcoin_changes_month_6 = data['changes']['price']['month_6']
    bitcoin_changes_year = data['changes']['price']['year']
    bitcoin_volume_percent = data['volume_percent']
    timestamp = data['timestamp']
    return {
        'Price': bitcoin_price,
        'High': bitcoin_high,
        'Low': bitcoin_low,
        'Volume': bitcoin_volume,
        'Open_Hour': bitcoin_open_hour,
        'Open_Day': bitcoin_open_day,
        'Open_Week': bitcoin_open_week,
        'Open_Month': bitcoin_open_month,
        'Open_Month_3': bitcoin_open_month_3,
        'Open_Month_6': bitcoin_open_month_6,
        'Open_Year': bitcoin_open_year,
        'Changes_Hour': bitcoin_changes_hour,
        'Changes_Day': bitcoin_changes_day,
        'Changes_Week': bitcoin_changes_week,
        'Changes_Month': bitcoin_changes_month,
        'Changes_Month_3': bitcoin_changes_month_3,
        'Changes_Month_6': bitcoin_changes_month_6,
        'Changes_Year': bitcoin_changes_year,
        'Volume_Percent': bitcoin_volume_percent,
        'Timestamp': timestamp
    }


# Function to predict future Bitcoin prices using MLPRegressor
def predict_future_prices(bitcoin_data, num_days=1):
    X = bitcoin_data.drop(columns=['Price', 'High', 'Low', 'Volume', 'Volume_Percent'])
    y = bitcoin_data['Price']
    model = MLPRegressor(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', max_iter=500)
    model.fit(X.values, y)
    future_index = len(bitcoin_data) + num_days
    future_price = model.predict([X.iloc[-1]])[0]  # Sử dụng dữ liệu cuối cùng để dự đoán
    return future_price, model


# Function to determine buy, sell, or hold signal
def determine_signal(current_price, predicted_price):
    if predicted_price > current_price:
        return "Buy"
    elif predicted_price < current_price:
        return "Sell"
    else:
        return "Hold"


# Main function for real-time prediction
def real_time_prediction(initial_samples=10, retrain_threshold=20, model_path="bitcoin_model_v3.pkl"):
    try:
        model = joblib.load(model_path)
        print("Model loaded successfully from", model_path)
    except Exception as e:
        print("Error loading model:", e)
        print("Initializing model to None.")
        model = None

    historical_data = pd.DataFrame(columns=['Price', 'High', 'Low', 'Volume', 'Open_Hour', 'Open_Day', 'Open_Week',
                                            'Open_Month', 'Open_Month_3', 'Open_Month_6', 'Open_Year',
                                            'Changes_Hour', 'Changes_Day', 'Changes_Week', 'Changes_Month',
                                            'Changes_Month_3', 'Changes_Month_6', 'Changes_Year', 'Volume_Percent',
                                            'Timestamp'])
    prediction_count = 0
    wrong_predictions = 0
    correct_predictions = 0
    total_predictions = 0

    # Fetch initial historical data for a certain number of samples
    while prediction_count < initial_samples:
        bitcoin_data = get_bitcoin_data()
        if bitcoin_data is not None:
            print("Train sample:", bitcoin_data)
            historical_data = pd.concat([historical_data, pd.DataFrame(bitcoin_data, index=[0])], ignore_index=True)
            prediction_count += 1
            time.sleep(10)  # Wait for 1 second before fetching next sample

    # Enter real-time prediction loop
    while True:
        current_data = get_bitcoin_data()
        if current_data is not None:
            historical_data = pd.concat([historical_data, pd.DataFrame(current_data, index=[0])], ignore_index=True)

            # Predict and determine signal for the current price
            predicted_price, model = predict_future_prices(historical_data)
            current_price = current_data['Price']
            signal = determine_signal(current_price, predicted_price)
            print("Current Bitcoin Price:", current_price)
            print("Predicted Price (10 seconds later):", predicted_price)
            print("Signal:", signal, "| Time:", pd.Timestamp.now())
            total_predictions += 1
            time.sleep(10)

            new_price_check = get_bitcoin_data()['Price']
            print("Price after check:", new_price_check)

            if signal == "Buy":
                if new_price_check > current_price:
                    correct_predictions += 1
                    print("Correct prediction!")
                else:
                    wrong_predictions += 1
                    print("Wrong prediction!")
            elif signal == "Sell":
                if new_price_check < current_price:
                    correct_predictions += 1
                    print("Correct prediction!")
                else:
                    wrong_predictions += 1
                    print("Wrong prediction!")

            # If too many wrong predictions, retrain the model
            if wrong_predictions >= 5:
                print("The prediction: Correct prediction ", correct_predictions, "Wrong prediction ",
                      wrong_predictions)
                print("\nRetraining the model with updated data...\n")
                historical_data = historical_data.iloc[
                                  -retrain_threshold:]  # Keep only the last 'retrain_threshold' samples
                predicted_price, model = predict_future_prices(historical_data)
                signal = determine_signal(current_price, predicted_price)
                print("New Prediction:", "| Predicted Price:", predicted_price, "| Signal:", signal, "| Time:",
                      pd.Timestamp.now())

                file_name = "log.txt"
                content = f"The prediction: Correct {correct_predictions}, Wrong {wrong_predictions}"
                if not os.path.exists(file_name):
                    with open(file_name, 'w') as file:
                        pass
                append_to_file(file_name, content)

                joblib.dump(model, model_path)
                wrong_predictions = 0
                correct_predictions = 0
                total_predictions = 0
                prediction_count = 0

            # If enough correct predictions in the recent past, continue with prediction
            if total_predictions == 10 and correct_predictions >= 5:
                print("\nEnough correct predictions in the recent past. Continuing with prediction...\n")
                wrong_predictions = 0
                correct_predictions = 0
                total_predictions = 0
                prediction_count = 0

        else:
            print("Error fetching current Bitcoin data. Retrying in 10 seconds...")
            time.sleep(10)  # Wait for 10 seconds before retrying


# Start real-time prediction
real_time_prediction()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator MLPRegressor from version 1.4.1.post1 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Model loaded successfully from bitcoin_model_v3.pkl
# Train sample: {'Price': 70431.05, 'High': 71536.54, 'Low': 69609.43, 'Volume': 25762.92317842, 'Open_Hour': 70402.57, 'Open_Day': 70792.27, 'Open_Week': 65682.3, 'Open_Month': 61903.0, 'Open_Month_3': 42437.6, 'Open_Month_6': 26958.69, 'Open_Year': 28099.53, 'Changes_Hour': 28.48, 'Changes_Day': -361.21, 'Changes_Week': 4748.76, 'Changes_Month': 8528.05, 'Changes_Month_3': 27993.45, 'Changes_Month_6': 43472.37, 'Changes_Year': 42331.52, 'Volume_Percent': 90.79, 'Timestamp': 1711689593}
# Train sample: {'Price': 70430.99, 'High': 71536.54, 'Low': 69609.43, 'Volume': 25762.43432137, 'Open_Hour': 70402.57, 'Open_Day': 70792.27, 'Open_Week': 65682.3, 'Open_Month': 61903.0, 'Open_Month_3': 42437.6, 'Open_Month_6': 26958.69, 'Open_Year': 28099.53, 'Changes_Hour': 28.42, 'Changes_Day': -361.27, 'Changes_Week': 4748.7, 'Changes_Month': 8527.99, 'Changes_Month_3': 27993.39, 'Changes_Month_6': 43472.3, 'Changes_Year': 42331.46, 'Volume_Percent': 90.79, 'Timestamp': 1711689603}
# Train sample: {'Price': 70430.99, 'High': 71536.54, 'Low': 69609.43, 'Volume': 25762.43432137, 'Open_Hour': 70402.57, 'Open_Day': 70792.27, 'Open_Week': 65682.3, 'Open_Month': 61903.0, 'Open_Month_3': 42437.6, 'Open_Month_6': 26958.69, 'Open_Year': 28099.53, 'Changes_Hour': 28.42, 'Changes_Day': -361.27, 'Changes_Week': 4748.7, 'Changes_Month': 8527.99, 'Changes_Month_3': 27993.39, 'Changes_Month_6': 43472.3, 'Changes_Year': 42331.46, 'Volume_Percent': 90.79, 'Timestamp': 1711689612}
# Train sample: {'Price': 70430.61, 'High': 71536.54, 'Low': 69620.3, 'Volume': 25762.17074593, 'Open_Hour': 70402.57, 'Open_Day': 70792.27, 'Open_Week': 65682.3, 'Open_Month': 61903.0, 'Open_Month_3': 42437.6, 'Open_Month_6': 26958.69, 'Open_Year': 28099.53, 'Changes_Hour': 28.04, 'Changes_Day': -361.66, 'Changes_Week': 4748.31, 'Changes_Month': 8527.61, 'Changes_Month_3': 27993.01, 'Changes_Month_6': 43471.92, 'Changes_Year': 42331.08, 'Volume_Percent': 90.79, 'Timestamp': 1711689624}
# Train sample: {'Price': 70430.61, 'High': 71536.54, 'Low': 69620.3, 'Volume': 25762.17074593, 'Open_Hour': 70402.57, 'Open_Day': 70792.27, 'Open_Week': 65682.3, 'Open_Month': 61903.0, 'Open_Month_3': 42437.6, 'Open_Month_6': 26958.69, 'Open_Year': 28099.53, 'Changes_Hour': 28.04, 'Changes_Day': -361.66, 'Changes_Week': 4748.31, 'Changes_Month': 8527.61, 'Changes_Month_3': 27993.01, 'Changes_Month_6': 43471.92, 'Changes_Year': 42331.08, 'Volume_Percent': 90.79, 'Timestamp': 1711689633}
# Train sample: {'Price': 70430.61, 'High': 71536.54, 'Low': 69620.3, 'Volume': 25762.17074593, 'Open_Hour': 70402.57, 'Open_Day': 70792.27, 'Open_Week': 65682.3, 'Open_Month': 61903.0, 'Open_Month_3': 42437.6, 'Open_Month_6': 26958.69, 'Open_Year': 28099.53, 'Changes_Hour': 28.04, 'Changes_Day': -361.66, 'Changes_Week': 4748.31, 'Changes_Month': 8527.61, 'Changes_Month_3': 27993.01, 'Changes_Month_6': 43471.92, 'Changes_Year': 42331.08, 'Volume_Percent': 90.79, 'Timestamp': 1711689642}
# Train sample: {'Price': 70430.61, 'High': 71536.54, 'Low': 69620.3, 'Volume': 25762.17074593, 'Open_Hour': 70402.57, 'Open_Day': 70792.27, 'Open_Week': 65682.3, 'Open_Month': 61903.0, 'Open_Month_3': 42437.6, 'Open_Month_6': 26958.69, 'Open_Year': 28099.53, 'Changes_Hour': 28.04, 'Changes_Day': -361.66, 'Changes_Week': 4748.31, 'Changes_Month': 8527.61, 'Changes_Month_3': 27993.01, 'Changes_Month_6': 43471.92, 'Changes_Year': 42331.08, 'Volume_Percent': 90.79, 'Timestamp': 1711689652}
# Train sample: {'Price': 70430.88, 'High': 71536.54, 'Low': 69620.3, 'Volume': 25761.96086031, 'Open_Hour': 70402.57, 'Open_Day': 70792.27, 'Open_Week': 65682.3, 'Open_Month': 61903.0, 'Open_Month_3': 42437.6, 'Open_Month_6': 26958.69, 'Open_Year': 28099.53, 'Changes_Hour': 28.3, 'Changes_Day': -361.39, 'Changes_Week': 4748.58, 'Changes_Month': 8527.88, 'Changes_Month_3': 27993.27, 'Changes_Month_6': 43472.19, 'Changes_Year': 42331.34, 'Volume_Percent': 90.79, 'Timestamp': 1711689663}
# Train sample: {'Price': 70429.52, 'High': 71536.54, 'Low': 69620.3, 'Volume': 25762.08202215, 'Open_Hour': 70402.57, 'Open_Day': 70792.27, 'Open_Week': 65682.3, 'Open_Month': 61903.0, 'Open_Month_3': 42437.6, 'Open_Month_6': 26958.69, 'Open_Year': 28099.53, 'Changes_Hour': 26.95, 'Changes_Day': -362.75, 'Changes_Week': 4747.22, 'Changes_Month': 8526.52, 'Changes_Month_3': 27991.91, 'Changes_Month_6': 43470.83, 'Changes_Year': 42329.98, 'Volume_Percent': 90.79, 'Timestamp': 1711689675}
# Train sample: {'Price': 70430.1, 'High': 71536.54, 'Low': 69626.79, 'Volume': 25761.92767883, 'Open_Hour': 70402.57, 'Open_Day': 70792.27, 'Open_Week': 65682.3, 'Open_Month': 61903.0, 'Open_Month_3': 42437.6, 'Open_Month_6': 26958.69, 'Open_Year': 28099.53, 'Changes_Hour': 27.53, 'Changes_Day': -362.16, 'Changes_Week': 4747.8, 'Changes_Month': 8527.1, 'Changes_Month_3': 27992.5, 'Changes_Month_6': 43471.41, 'Changes_Year': 42330.57, 'Volume_Percent': 90.79, 'Timestamp': 1711689684}
# Current Bitcoin Price: 70429.43
# Predicted Price (10 seconds later): -4179911.485379973
# Signal: Sell | Time: 2024-03-29 05:21:37.542695
# Price after check: 70428.5
# Correct prediction!
# Current Bitcoin Price: 70428.5
# Predicted Price (10 seconds later): 4730544.130405433
# Signal: Buy | Time: 2024-03-29 05:21:47.993680
# Price after check: 70428.45
# Wrong prediction!
# Current Bitcoin Price: 70428.45
# Predicted Price (10 seconds later): -2642694.4835081096
# Signal: Sell | Time: 2024-03-29 05:21:58.475804
# Price after check: 70428.34
# Correct prediction!
# Current Bitcoin Price: 70428.34
# Predicted Price (10 seconds later): -5623615.1556454515
# Signal: Sell | Time: 2024-03-29 05:22:08.905899
# Price after check: 70425.69
# Correct prediction!
# Current Bitcoin Price: 70425.69
# Predicted Price (10 seconds later): 24957672.624431998
# Signal: Buy | Time: 2024-03-29 05:22:19.341339
# Price after check: 70419.19
# Wrong prediction!
# Current Bitcoin Price: 70419.19
# Predicted Price (10 seconds later): 6587949.62706429
# Signal: Buy | Time: 2024-03-29 05:22:29.905865
# Price after check: 70417.55
# Wrong prediction!
# Current Bitcoin Price: 70417.55
# Predicted Price (10 seconds later): 570371.712276796
# Signal: Buy | Time: 2024-03-29 05:22:40.430744
# Price after check: 70417.55
# Wrong prediction!
# Current Bitcoin Price: 70417.55
# Predicted Price (10 seconds later): -30422330.56619565
# Signal: Sell | Time: 2024-03-29 05:22:50.871923
# Price after check: 70417.28
# Correct prediction!
# Current Bitcoin Price: 70417.28
# Predicted Price (10 seconds later): 27757980.83814603
# Signal: Buy | Time: 2024-03-29 05:23:01.347963
# Price after check: 70417.28
# Wrong prediction!
# The prediction: Correct prediction  4 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 1678037.2307383406 | Signal: Buy | Time: 2024-03-29 05:23:11.588473
# Current Bitcoin Price: 70417.28
# Predicted Price (10 seconds later): -34335599.77189361
# Signal: Sell | Time: 2024-03-29 05:23:11.960010
# Price after check: 70417.21
# Correct prediction!
# Current Bitcoin Price: 70417.21
# Predicted Price (10 seconds later): 6167333.9515812
# Signal: Buy | Time: 2024-03-29 05:23:22.403619
# Price after check: 70417.18
# Wrong prediction!
# Current Bitcoin Price: 70417.18
# Predicted Price (10 seconds later): 7032668.928438765
# Signal: Buy | Time: 2024-03-29 05:23:32.891978
# Price after check: 70413.41
# Wrong prediction!
# Current Bitcoin Price: 70413.41
# Predicted Price (10 seconds later): 39617357.023497045
# Signal: Buy | Time: 2024-03-29 05:23:43.322661
# Price after check: 70412.5
# Wrong prediction!
# Current Bitcoin Price: 70412.5
# Predicted Price (10 seconds later): 39202873.807920106
# Signal: Buy | Time: 2024-03-29 05:23:53.749688
# Price after check: 70409.71
# Wrong prediction!
# Current Bitcoin Price: 70409.71
# Predicted Price (10 seconds later): 27188546.33676034
# Signal: Buy | Time: 2024-03-29 05:24:04.231085
# Price after check: 70409.71
# Wrong prediction!
# The prediction: Correct prediction  1 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 27209074.38864655 | Signal: Buy | Time: 2024-03-29 05:24:14.478882
# Current Bitcoin Price: 70409.71
# Predicted Price (10 seconds later): 26419389.027556945
# Signal: Buy | Time: 2024-03-29 05:24:14.700291
# Price after check: 70399.55
# Wrong prediction!
# Current Bitcoin Price: 70399.55
# Predicted Price (10 seconds later): -2387138.9579549916
# Signal: Sell | Time: 2024-03-29 05:24:25.163134
# Price after check: 70397.93
# Correct prediction!
# Current Bitcoin Price: 70397.93
# Predicted Price (10 seconds later): 8421834.84740906
# Signal: Buy | Time: 2024-03-29 05:24:35.711541
# Price after check: 70385.38
# Wrong prediction!
# Current Bitcoin Price: 70385.38
# Predicted Price (10 seconds later): 14807099.464920169
# Signal: Buy | Time: 2024-03-29 05:24:46.147951
# Price after check: 70386.16
# Correct prediction!
# Current Bitcoin Price: 70386.16
# Predicted Price (10 seconds later): 3973471.2039589523
# Signal: Buy | Time: 2024-03-29 05:24:56.585741
# Price after check: 70386.16
# Wrong prediction!
# Current Bitcoin Price: 70386.16
# Predicted Price (10 seconds later): -51816179.45082183
# Signal: Sell | Time: 2024-03-29 05:25:07.045035
# Price after check: 70384.37
# Correct prediction!
# Current Bitcoin Price: 70384.37
# Predicted Price (10 seconds later): -3406710.6213631625
# Signal: Sell | Time: 2024-03-29 05:25:17.485800
# Price after check: 70382.7
# Correct prediction!
# Current Bitcoin Price: 70382.7
# Predicted Price (10 seconds later): 42020219.62823833
# Signal: Buy | Time: 2024-03-29 05:25:27.943831
# Price after check: 70382.65
# Wrong prediction!
# Current Bitcoin Price: 70382.65
# Predicted Price (10 seconds later): 300813.9511490782
# Signal: Buy | Time: 2024-03-29 05:25:38.402426
# Price after check: 70382.65
# Wrong prediction!
# The prediction: Correct prediction  4 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 20925849.36130955 | Signal: Buy | Time: 2024-03-29 05:25:48.633756
# Current Bitcoin Price: 70382.65
# Predicted Price (10 seconds later): -9352185.04209237
# Signal: Sell | Time: 2024-03-29 05:25:48.848686
# Price after check: 70383.9
# Wrong prediction!
# Current Bitcoin Price: 70383.9
# Predicted Price (10 seconds later): -5890480.228166197
# Signal: Sell | Time: 2024-03-29 05:25:59.311608
# Price after check: 70383.95
# Wrong prediction!
# Current Bitcoin Price: 70383.95
# Predicted Price (10 seconds later): 23571791.73248986
# Signal: Buy | Time: 2024-03-29 05:26:09.756770
# Price after check: 70384.67
# Correct prediction!
# Current Bitcoin Price: 70384.67
# Predicted Price (10 seconds later): 13005491.76559609
# Signal: Buy | Time: 2024-03-29 05:26:20.206833
# Price after check: 70386.42
# Correct prediction!
# Current Bitcoin Price: 70386.42
# Predicted Price (10 seconds later): -8059215.495575505
# Signal: Sell | Time: 2024-03-29 05:26:30.750317
# Price after check: 70386.42
# Wrong prediction!
# Current Bitcoin Price: 70386.42
# Predicted Price (10 seconds later): -9374150.543587817
# Signal: Sell | Time: 2024-03-29 05:26:41.214684
# Price after check: 70387.16
# Wrong prediction!
# Current Bitcoin Price: 70387.16
# Predicted Price (10 seconds later): 18956440.25972343
# Signal: Buy | Time: 2024-03-29 05:26:51.658661
# Price after check: 70387.92
# Correct prediction!
# Current Bitcoin Price: 70387.92
# Predicted Price (10 seconds later): -5480188.704006998
# Signal: Sell | Time: 2024-03-29 05:27:02.109058
# Price after check: 70392.83
# Wrong prediction!
# The prediction: Correct prediction  3 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -3532283.602672349 | Signal: Sell | Time: 2024-03-29 05:27:12.348528
# Current Bitcoin Price: 70392.83
# Predicted Price (10 seconds later): 11769077.595456619
# Signal: Buy | Time: 2024-03-29 05:27:12.583071
# Price after check: 70396.2
# Correct prediction!
# Current Bitcoin Price: 70396.2
# Predicted Price (10 seconds later): 15027721.19905762
# Signal: Buy | Time: 2024-03-29 05:27:23.034639
# Price after check: 70396.35
# Correct prediction!
# Current Bitcoin Price: 70396.35
# Predicted Price (10 seconds later): -20220509.29972767
# Signal: Sell | Time: 2024-03-29 05:27:33.468112
# Price after check: 70397.32
# Wrong prediction!
# Current Bitcoin Price: 70397.32
# Predicted Price (10 seconds later): -3001069.9796398156
# Signal: Sell | Time: 2024-03-29 05:27:43.919980
# Price after check: 70397.32
# Wrong prediction!
# Current Bitcoin Price: 70397.32
# Predicted Price (10 seconds later): -18217215.797770992
# Signal: Sell | Time: 2024-03-29 05:27:54.378728
# Price after check: 70397.15
# Correct prediction!
# Current Bitcoin Price: 70397.15
# Predicted Price (10 seconds later): -240828.20973809302
# Signal: Sell | Time: 2024-03-29 05:28:04.851757
# Price after check: 70396.83
# Correct prediction!
# Current Bitcoin Price: 70396.83
# Predicted Price (10 seconds later): 2237717.5243662833
# Signal: Buy | Time: 2024-03-29 05:28:15.414582
# Price after check: 70400.19
# Correct prediction!
# Current Bitcoin Price: 70400.19
# Predicted Price (10 seconds later): 8139879.319082248
# Signal: Buy | Time: 2024-03-29 05:28:25.913583
# Price after check: 70400.02
# Wrong prediction!
# Current Bitcoin Price: 70400.02
# Predicted Price (10 seconds later): -36702276.21000602
# Signal: Sell | Time: 2024-03-29 05:28:36.337694
# Price after check: 70400.46
# Wrong prediction!
# Current Bitcoin Price: 70400.46
# Predicted Price (10 seconds later): 5439152.321802458
# Signal: Buy | Time: 2024-03-29 05:28:46.804623
# Price after check: 70400.75
# Correct prediction!
#
# Enough correct predictions in the recent past. Continuing with prediction...
#
# Current Bitcoin Price: 70400.75
# Predicted Price (10 seconds later): 14062112.900495917
# Signal: Buy | Time: 2024-03-29 05:28:57.236939
# Price after check: 70400.75
# Wrong prediction!
# Current Bitcoin Price: 70400.75
# Predicted Price (10 seconds later): 19985614.23731016
# Signal: Buy | Time: 2024-03-29 05:29:07.674363
# Price after check: 70401.54
# Correct prediction!
# Current Bitcoin Price: 70401.54
# Predicted Price (10 seconds later): -684905.039051347
# Signal: Sell | Time: 2024-03-29 05:29:18.169973
# Price after check: 70403.65
# Wrong prediction!
# Current Bitcoin Price: 70403.65
# Predicted Price (10 seconds later): 12234345.48064357
# Signal: Buy | Time: 2024-03-29 05:29:28.703690
# Price after check: 70404.41
# Correct prediction!
# Current Bitcoin Price: 70404.41
# Predicted Price (10 seconds later): -57536266.71053527
# Signal: Sell | Time: 2024-03-29 05:29:39.140422
# Price after check: 70405.32
# Wrong prediction!
# Current Bitcoin Price: 70405.32
# Predicted Price (10 seconds later): 5390389.997356882
# Signal: Buy | Time: 2024-03-29 05:29:49.586843
# Price after check: 70405.32
# Wrong prediction!
# Current Bitcoin Price: 70405.32
# Predicted Price (10 seconds later): 83938966.99855249
# Signal: Buy | Time: 2024-03-29 05:30:00.056950
# Price after check: 70405.32
# Wrong prediction!
# The prediction: Correct prediction  2 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 8443772.989363428 | Signal: Buy | Time: 2024-03-29 05:30:10.331956
# Current Bitcoin Price: 70405.32
# Predicted Price (10 seconds later): 7172898.87109013
# Signal: Buy | Time: 2024-03-29 05:30:10.661264
# Price after check: 70405.79
# Correct prediction!
# Current Bitcoin Price: 70405.79
# Predicted Price (10 seconds later): -27352217.60045894
# Signal: Sell | Time: 2024-03-29 05:30:21.198530
# Price after check: 70405.9
# Wrong prediction!
# Current Bitcoin Price: 70405.9
# Predicted Price (10 seconds later): -3863418.473816281
# Signal: Sell | Time: 2024-03-29 05:30:31.637985
# Price after check: 70410.8
# Wrong prediction!
# Current Bitcoin Price: 70410.8
# Predicted Price (10 seconds later): 3234634.207231624
# Signal: Buy | Time: 2024-03-29 05:30:42.142957
# Price after check: 70410.75
# Wrong prediction!
# Current Bitcoin Price: 70410.75
# Predicted Price (10 seconds later): -890955.735077261
# Signal: Sell | Time: 2024-03-29 05:30:52.588598
# Price after check: 70410.47
# Correct prediction!
# Current Bitcoin Price: 70410.47
# Predicted Price (10 seconds later): -2728298.3850452118
# Signal: Sell | Time: 2024-03-29 05:31:03.055719
# Price after check: 70410.0
# Correct prediction!
# Current Bitcoin Price: 70410.0
# Predicted Price (10 seconds later): 9117560.398329042
# Signal: Buy | Time: 2024-03-29 05:31:13.480639
# Price after check: 70410.75
# Correct prediction!
# Current Bitcoin Price: 70410.75
# Predicted Price (10 seconds later): -2473729.0450576325
# Signal: Sell | Time: 2024-03-29 05:31:23.943586
# Price after check: 70409.15
# Correct prediction!
# Current Bitcoin Price: 70409.15
# Predicted Price (10 seconds later): 5776511.273194102
# Signal: Buy | Time: 2024-03-29 05:31:34.390567
# Price after check: 70407.48
# Wrong prediction!
# Current Bitcoin Price: 70407.48
# Predicted Price (10 seconds later): -19113506.267887488
# Signal: Sell | Time: 2024-03-29 05:31:44.825126
# Price after check: 70402.32
# Correct prediction!
#
# Enough correct predictions in the recent past. Continuing with prediction...
#
# Current Bitcoin Price: 70402.32
# Predicted Price (10 seconds later): 17995516.051795576
# Signal: Buy | Time: 2024-03-29 05:31:55.274769
# Price after check: 70402.41
# Correct prediction!
# Current Bitcoin Price: 70402.41
# Predicted Price (10 seconds later): -8513597.207247267
# Signal: Sell | Time: 2024-03-29 05:32:05.761906
# Price after check: 70402.27
# Correct prediction!
# Current Bitcoin Price: 70402.27
# Predicted Price (10 seconds later): 5589453.048426199
# Signal: Buy | Time: 2024-03-29 05:32:16.286443
# Price after check: 70402.3
# Correct prediction!
# Current Bitcoin Price: 70402.3
# Predicted Price (10 seconds later): 6595744.91692418
# Signal: Buy | Time: 2024-03-29 05:32:26.857470
# Price after check: 70402.09
# Wrong prediction!
# Current Bitcoin Price: 70402.09
# Predicted Price (10 seconds later): 1791490.1115308227
# Signal: Buy | Time: 2024-03-29 05:32:37.302594
# Price after check: 70402.09
# Wrong prediction!
# Current Bitcoin Price: 70402.09
# Predicted Price (10 seconds later): 4588055.359711498
# Signal: Buy | Time: 2024-03-29 05:32:47.859906
# Price after check: 70401.2
# Wrong prediction!
# Current Bitcoin Price: 70401.2
# Predicted Price (10 seconds later): 41961389.59109023
# Signal: Buy | Time: 2024-03-29 05:32:58.328225
# Price after check: 70399.71
# Wrong prediction!
# Current Bitcoin Price: 70399.71
# Predicted Price (10 seconds later): -2642603.1283791927
# Signal: Sell | Time: 2024-03-29 05:33:08.758880
# Price after check: 70396.42
# Correct prediction!
# Current Bitcoin Price: 70396.42
# Predicted Price (10 seconds later): -3069961.4994545933
# Signal: Sell | Time: 2024-03-29 05:33:19.183076
# Price after check: 70396.86
# Wrong prediction!
# The prediction: Correct prediction  4 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 11714575.750736363 | Signal: Buy | Time: 2024-03-29 05:33:29.470256
# Current Bitcoin Price: 70396.86
# Predicted Price (10 seconds later): 10750875.279766062
# Signal: Buy | Time: 2024-03-29 05:33:29.692150
# Price after check: 70396.8
# Wrong prediction!
# Current Bitcoin Price: 70396.8
# Predicted Price (10 seconds later): -2899269.0131469355
# Signal: Sell | Time: 2024-03-29 05:33:40.155940
# Price after check: 70396.8
# Wrong prediction!
# Current Bitcoin Price: 70396.8
# Predicted Price (10 seconds later): -35822433.923744515
# Signal: Sell | Time: 2024-03-29 05:33:50.598040
# Price after check: 70396.04
# Correct prediction!
# Current Bitcoin Price: 70396.04
# Predicted Price (10 seconds later): 28777328.096888274
# Signal: Buy | Time: 2024-03-29 05:34:01.058644
# Price after check: 70396.02
# Wrong prediction!
# Current Bitcoin Price: 70396.02
# Predicted Price (10 seconds later): -4527003.390625267
# Signal: Sell | Time: 2024-03-29 05:34:11.594332
# Price after check: 70396.05
# Wrong prediction!
# Current Bitcoin Price: 70396.05
# Predicted Price (10 seconds later): 66667927.828332156
# Signal: Buy | Time: 2024-03-29 05:34:22.019867
# Price after check: 70395.99
# Wrong prediction!
# The prediction: Correct prediction  1 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -26446968.978285994 | Signal: Sell | Time: 2024-03-29 05:34:32.279682
# Current Bitcoin Price: 70395.99
# Predicted Price (10 seconds later): 5095010.0479593715
# Signal: Buy | Time: 2024-03-29 05:34:32.500829
# Price after check: 70395.99
# Wrong prediction!
# Current Bitcoin Price: 70395.99
# Predicted Price (10 seconds later): 14926502.133905614
# Signal: Buy | Time: 2024-03-29 05:34:42.939874
# Price after check: 70395.44
# Wrong prediction!
# Current Bitcoin Price: 70395.44
# Predicted Price (10 seconds later): 851499.1879306921
# Signal: Buy | Time: 2024-03-29 05:34:53.383866
# Price after check: 70395.34
# Wrong prediction!
# Current Bitcoin Price: 70395.34
# Predicted Price (10 seconds later): -12325851.386340035
# Signal: Sell | Time: 2024-03-29 05:35:03.879825
# Price after check: 70395.25
# Correct prediction!
# Current Bitcoin Price: 70395.25
# Predicted Price (10 seconds later): 12861463.7118357
# Signal: Buy | Time: 2024-03-29 05:35:14.371001
# Price after check: 70391.91
# Wrong prediction!
# Current Bitcoin Price: 70391.91
# Predicted Price (10 seconds later): -3609658.088583492
# Signal: Sell | Time: 2024-03-29 05:35:24.808971
# Price after check: 70391.91
# Wrong prediction!
# The prediction: Correct prediction  1 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 1066866.645403001 | Signal: Buy | Time: 2024-03-29 05:35:35.105727
# Current Bitcoin Price: 70391.91
# Predicted Price (10 seconds later): 32026545.54337563
# Signal: Buy | Time: 2024-03-29 05:35:35.328603
# Price after check: 70391.57
# Wrong prediction!
# Current Bitcoin Price: 70391.57
# Predicted Price (10 seconds later): -27301783.392483864
# Signal: Sell | Time: 2024-03-29 05:35:45.749851
# Price after check: 70391.46
# Correct prediction!
# Current Bitcoin Price: 70391.46
# Predicted Price (10 seconds later): -20864048.859540004
# Signal: Sell | Time: 2024-03-29 05:35:56.184103
# Price after check: 70390.96
# Correct prediction!
# Current Bitcoin Price: 70390.96
# Predicted Price (10 seconds later): 3697424.5493130833
# Signal: Buy | Time: 2024-03-29 05:36:06.764648
# Price after check: 70390.81
# Wrong prediction!
# Current Bitcoin Price: 70390.81
# Predicted Price (10 seconds later): 1238869.5487233442
# Signal: Buy | Time: 2024-03-29 05:36:17.265305
# Price after check: 70386.9
# Wrong prediction!
# Current Bitcoin Price: 70386.9
# Predicted Price (10 seconds later): 13248144.87511485
# Signal: Buy | Time: 2024-03-29 05:36:27.696777
# Price after check: 70386.9
# Wrong prediction!
# Current Bitcoin Price: 70386.9
# Predicted Price (10 seconds later): 13821384.524294138
# Signal: Buy | Time: 2024-03-29 05:36:38.173166
# Price after check: 70386.9
# Wrong prediction!
# The prediction: Correct prediction  2 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 5821029.963598469 | Signal: Buy | Time: 2024-03-29 05:36:48.415302
# Current Bitcoin Price: 70386.9
# Predicted Price (10 seconds later): -42035093.51325049
# Signal: Sell | Time: 2024-03-29 05:36:48.637836
# Price after check: 70386.85
# Correct prediction!
# Current Bitcoin Price: 70386.85
# Predicted Price (10 seconds later): -1580520.597475369
# Signal: Sell | Time: 2024-03-29 05:36:59.096586
# Price after check: 70386.85
# Wrong prediction!
# Current Bitcoin Price: 70386.85
# Predicted Price (10 seconds later): 12552934.174012363
# Signal: Buy | Time: 2024-03-29 05:37:09.556568
# Price after check: 70385.95
# Wrong prediction!
# Current Bitcoin Price: 70385.95
# Predicted Price (10 seconds later): 11396030.507360071
# Signal: Buy | Time: 2024-03-29 05:37:19.997720
# Price after check: 70274.29
# Wrong prediction!
# Current Bitcoin Price: 70274.29
# Predicted Price (10 seconds later): -123783385.99644819
# Signal: Sell | Time: 2024-03-29 05:37:30.431216
# Price after check: 70269.18
# Correct prediction!
# Current Bitcoin Price: 70269.18
# Predicted Price (10 seconds later): -7300368.898037802
# Signal: Sell | Time: 2024-03-29 05:37:40.915377
# Price after check: 70269.48
# Wrong prediction!
# Current Bitcoin Price: 70269.48
# Predicted Price (10 seconds later): 13102047.135233533
# Signal: Buy | Time: 2024-03-29 05:37:51.362286
# Price after check: 70269.21
# Wrong prediction!
# The prediction: Correct prediction  2 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 16318411.818013666 | Signal: Buy | Time: 2024-03-29 05:38:01.653955
# Current Bitcoin Price: 70269.21
# Predicted Price (10 seconds later): 9040697.368283303
# Signal: Buy | Time: 2024-03-29 05:38:01.914937
# Price after check: 70269.21
# Wrong prediction!
# Current Bitcoin Price: 70269.21
# Predicted Price (10 seconds later): 6290806.255027751
# Signal: Buy | Time: 2024-03-29 05:38:12.485118
# Price after check: 70266.2
# Wrong prediction!
# Current Bitcoin Price: 70266.2
# Predicted Price (10 seconds later): 22544594.202258877
# Signal: Buy | Time: 2024-03-29 05:38:22.920848
# Price after check: 70266.23
# Correct prediction!
# Current Bitcoin Price: 70266.23
# Predicted Price (10 seconds later): -4817222.749202006
# Signal: Sell | Time: 2024-03-29 05:38:33.359771
# Price after check: 70268.2
# Wrong prediction!
# Current Bitcoin Price: 70268.2
# Predicted Price (10 seconds later): 10507134.859685684
# Signal: Buy | Time: 2024-03-29 05:38:43.810669
# Price after check: 70267.98
# Wrong prediction!
# Current Bitcoin Price: 70267.98
# Predicted Price (10 seconds later): -78830342.29619963
# Signal: Sell | Time: 2024-03-29 05:38:54.369756
# Price after check: 70268.62
# Wrong prediction!
# The prediction: Correct prediction  1 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -1843123.2894489765 | Signal: Sell | Time: 2024-03-29 05:39:04.605340
# Current Bitcoin Price: 70268.62
# Predicted Price (10 seconds later): -34024222.34017627
# Signal: Sell | Time: 2024-03-29 05:39:04.826713
# Price after check: 70268.62
# Wrong prediction!
# Current Bitcoin Price: 70268.62
# Predicted Price (10 seconds later): -1116190.45473095
# Signal: Sell | Time: 2024-03-29 05:39:15.288703
# Price after check: 70268.34
# Correct prediction!
# Current Bitcoin Price: 70268.34
# Predicted Price (10 seconds later): -4071365.2279120027
# Signal: Sell | Time: 2024-03-29 05:39:25.741626
# Price after check: 70268.48
# Wrong prediction!
# Current Bitcoin Price: 70268.48
# Predicted Price (10 seconds later): 4647709.92141915
# Signal: Buy | Time: 2024-03-29 05:39:36.175149
# Price after check: 70271.9
# Correct prediction!
# Current Bitcoin Price: 70271.9
# Predicted Price (10 seconds later): -30890479.95021495
# Signal: Sell | Time: 2024-03-29 05:39:46.633578
# Price after check: 70271.06
# Correct prediction!
# Current Bitcoin Price: 70271.06
# Predicted Price (10 seconds later): -24120098.0616962
# Signal: Sell | Time: 2024-03-29 05:39:57.055914
# Price after check: 70271.06
# Wrong prediction!
# Current Bitcoin Price: 70271.06
# Predicted Price (10 seconds later): -41100537.04107094
# Signal: Sell | Time: 2024-03-29 05:40:07.660531
# Price after check: 70271.16
# Wrong prediction!
# Current Bitcoin Price: 70271.16
# Predicted Price (10 seconds later): 57172399.52225172
# Signal: Buy | Time: 2024-03-29 05:40:18.203491
# Price after check: 70271.92
# Correct prediction!
# Current Bitcoin Price: 70271.92
# Predicted Price (10 seconds later): -3786529.244079445
# Signal: Sell | Time: 2024-03-29 05:40:28.643945
# Price after check: 70271.92
# Wrong prediction!
# The prediction: Correct prediction  4 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 9104578.619426608 | Signal: Buy | Time: 2024-03-29 05:40:38.877735
# Current Bitcoin Price: 70271.92
# Predicted Price (10 seconds later): 15650235.08270512
# Signal: Buy | Time: 2024-03-29 05:40:39.106619
# Price after check: 70271.92
# Wrong prediction!
# Current Bitcoin Price: 70271.92
# Predicted Price (10 seconds later): 1145355.6971988743
# Signal: Buy | Time: 2024-03-29 05:40:49.572898
# Price after check: 70271.79
# Wrong prediction!
# Current Bitcoin Price: 70271.79
# Predicted Price (10 seconds later): -1543253.114461916
# Signal: Sell | Time: 2024-03-29 05:41:00.031383
# Price after check: 70270.89
# Correct prediction!
# Current Bitcoin Price: 70270.89
# Predicted Price (10 seconds later): -11856164.198719975
# Signal: Sell | Time: 2024-03-29 05:41:10.468057
# Price after check: 70271.43
# Wrong prediction!
# Current Bitcoin Price: 70271.43
# Predicted Price (10 seconds later): 4608117.917924122
# Signal: Buy | Time: 2024-03-29 05:41:20.927987
# Price after check: 70271.59
# Correct prediction!
# Current Bitcoin Price: 70271.59
# Predicted Price (10 seconds later): -32947162.389235765
# Signal: Sell | Time: 2024-03-29 05:41:31.470514
# Price after check: 70272.12
# Wrong prediction!
# Current Bitcoin Price: 70272.12
# Predicted Price (10 seconds later): -95460187.95589465
# Signal: Sell | Time: 2024-03-29 05:41:41.917756
# Price after check: 70272.12
# Wrong prediction!
# The prediction: Correct prediction  2 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -4309977.650213471 | Signal: Sell | Time: 2024-03-29 05:41:52.186406
# Current Bitcoin Price: 70272.12
# Predicted Price (10 seconds later): 37879214.97110663
# Signal: Buy | Time: 2024-03-29 05:41:52.422692
# Price after check: 70272.38
# Correct prediction!
# Current Bitcoin Price: 70272.38
# Predicted Price (10 seconds later): 301370.2702412448
# Signal: Buy | Time: 2024-03-29 05:42:02.955929
# Price after check: 70272.41
# Correct prediction!
# Current Bitcoin Price: 70272.41
# Predicted Price (10 seconds later): 7666958.837002108
# Signal: Buy | Time: 2024-03-29 05:42:13.448672
# Price after check: 70272.75
# Correct prediction!
# Current Bitcoin Price: 70272.75
# Predicted Price (10 seconds later): -5240354.258508749
# Signal: Sell | Time: 2024-03-29 05:42:23.917727
# Price after check: 70273.18
# Wrong prediction!
# Current Bitcoin Price: 70273.18
# Predicted Price (10 seconds later): 41230606.93664323
# Signal: Buy | Time: 2024-03-29 05:42:34.350719
# Price after check: 70272.97
# Wrong prediction!
# Current Bitcoin Price: 70272.97
# Predicted Price (10 seconds later): 14423934.129527962
# Signal: Buy | Time: 2024-03-29 05:42:44.796789
# Price after check: 70272.97
# Wrong prediction!
# Current Bitcoin Price: 70272.97
# Predicted Price (10 seconds later): 2943755.2469505547
# Signal: Buy | Time: 2024-03-29 05:42:55.282757
# Price after check: 70286.21
# Correct prediction!
# Current Bitcoin Price: 70286.21
# Predicted Price (10 seconds later): 3567674.1996752126
# Signal: Buy | Time: 2024-03-29 05:43:05.805855
# Price after check: 70287.62
# Correct prediction!
# Current Bitcoin Price: 70287.62
# Predicted Price (10 seconds later): -2670195.635393562
# Signal: Sell | Time: 2024-03-29 05:43:16.214439
# Price after check: 70288.11
# Wrong prediction!
# Current Bitcoin Price: 70288.11
# Predicted Price (10 seconds later): 20732639.248604193
# Signal: Buy | Time: 2024-03-29 05:43:26.704265
# Price after check: 70287.88
# Wrong prediction!
# The prediction: Correct prediction  5 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 6122399.406908133 | Signal: Buy | Time: 2024-03-29 05:43:36.933789
# Current Bitcoin Price: 70287.88
# Predicted Price (10 seconds later): -4074009.4677043357
# Signal: Sell | Time: 2024-03-29 05:43:37.169921
# Price after check: 70287.88
# Wrong prediction!
# Current Bitcoin Price: 70287.88
# Predicted Price (10 seconds later): -20927510.258553512
# Signal: Sell | Time: 2024-03-29 05:43:47.613047
# Price after check: 70287.88
# Wrong prediction!
# Current Bitcoin Price: 70287.88
# Predicted Price (10 seconds later): -19493337.458971504
# Signal: Sell | Time: 2024-03-29 05:43:58.155754
# Price after check: 70287.88
# Wrong prediction!
# Current Bitcoin Price: 70287.88
# Predicted Price (10 seconds later): -46164558.19723003
# Signal: Sell | Time: 2024-03-29 05:44:08.585839
# Price after check: 70287.66
# Correct prediction!
# Current Bitcoin Price: 70287.66
# Predicted Price (10 seconds later): -734827.0880854328
# Signal: Sell | Time: 2024-03-29 05:44:19.035779
# Price after check: 70287.1
# Correct prediction!
# Current Bitcoin Price: 70287.1
# Predicted Price (10 seconds later): 1118372.4605772772
# Signal: Buy | Time: 2024-03-29 05:44:29.517953
# Price after check: 70287.1
# Wrong prediction!
# Current Bitcoin Price: 70287.1
# Predicted Price (10 seconds later): 13932893.155232437
# Signal: Buy | Time: 2024-03-29 05:44:39.952619
# Price after check: 70288.14
# Correct prediction!
# Current Bitcoin Price: 70288.14
# Predicted Price (10 seconds later): -50358098.528129555
# Signal: Sell | Time: 2024-03-29 05:44:50.382303
# Price after check: 70288.08
# Correct prediction!
# Current Bitcoin Price: 70288.08
# Predicted Price (10 seconds later): 1630039.5270094534
# Signal: Buy | Time: 2024-03-29 05:45:00.848541
# Price after check: 70288.08
# Wrong prediction!
# The prediction: Correct prediction  4 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -48622441.986448705 | Signal: Sell | Time: 2024-03-29 05:45:11.070511
# Current Bitcoin Price: 70288.08
# Predicted Price (10 seconds later): -56590200.48260213
# Signal: Sell | Time: 2024-03-29 05:45:11.292832
# Price after check: 70287.49
# Correct prediction!
# Current Bitcoin Price: 70287.49
# Predicted Price (10 seconds later): -59782529.29111698
# Signal: Sell | Time: 2024-03-29 05:45:21.738814
# Price after check: 70287.49
# Wrong prediction!
# Current Bitcoin Price: 70287.49
# Predicted Price (10 seconds later): -7129879.6577015035
# Signal: Sell | Time: 2024-03-29 05:45:32.202542
# Price after check: 70287.71
# Wrong prediction!
# Current Bitcoin Price: 70287.71
# Predicted Price (10 seconds later): 18913927.5219034
# Signal: Buy | Time: 2024-03-29 05:45:42.631648
# Price after check: 70287.71
# Wrong prediction!
# Current Bitcoin Price: 70287.71
# Predicted Price (10 seconds later): 11587063.45485063
# Signal: Buy | Time: 2024-03-29 05:45:53.160652
# Price after check: 70287.74
# Correct prediction!
# Current Bitcoin Price: 70287.74
# Predicted Price (10 seconds later): 2276866.277107586
# Signal: Buy | Time: 2024-03-29 05:46:03.678974
# Price after check: 70288.64
# Correct prediction!
# Current Bitcoin Price: 70288.64
# Predicted Price (10 seconds later): -7671652.541159213
# Signal: Sell | Time: 2024-03-29 05:46:14.119692
# Price after check: 70291.17
# Wrong prediction!
# Current Bitcoin Price: 70291.17
# Predicted Price (10 seconds later): 15021032.4417857
# Signal: Buy | Time: 2024-03-29 05:46:24.548005
# Price after check: 70292.2
# Correct prediction!
# Current Bitcoin Price: 70292.2
# Predicted Price (10 seconds later): 26596056.36762974
# Signal: Buy | Time: 2024-03-29 05:46:35.007799
# Price after check: 70291.96
# Wrong prediction!
# The prediction: Correct prediction  4 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -3666576.010999182 | Signal: Sell | Time: 2024-03-29 05:46:45.258156
# Current Bitcoin Price: 70291.96
# Predicted Price (10 seconds later): -14903509.28367202
# Signal: Sell | Time: 2024-03-29 05:46:45.483992
# Price after check: 70296.48
# Wrong prediction!
# Current Bitcoin Price: 70296.48
# Predicted Price (10 seconds later): -7451803.969959304
# Signal: Sell | Time: 2024-03-29 05:46:55.931681
# Price after check: 70296.23
# Correct prediction!
# Current Bitcoin Price: 70296.23
# Predicted Price (10 seconds later): 31120469.920242567
# Signal: Buy | Time: 2024-03-29 05:47:06.382925
# Price after check: 70296.23
# Wrong prediction!
# Current Bitcoin Price: 70296.23
# Predicted Price (10 seconds later): 9503346.503260953
# Signal: Buy | Time: 2024-03-29 05:47:16.818602
# Price after check: 70295.74
# Wrong prediction!
# Current Bitcoin Price: 70295.74
# Predicted Price (10 seconds later): 19905301.508340485
# Signal: Buy | Time: 2024-03-29 05:47:27.276738
# Price after check: 70294.55
# Wrong prediction!
# Current Bitcoin Price: 70294.55
# Predicted Price (10 seconds later): 10605525.957462532
# Signal: Buy | Time: 2024-03-29 05:47:37.787873
# Price after check: 70294.55
# Wrong prediction!
# The prediction: Correct prediction  1 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -3820830.038403014 | Signal: Sell | Time: 2024-03-29 05:47:48.077384
# Current Bitcoin Price: 70294.55
# Predicted Price (10 seconds later): -35356901.70695625
# Signal: Sell | Time: 2024-03-29 05:47:48.351966
# Price after check: 70291.83
# Correct prediction!
# Current Bitcoin Price: 70291.83
# Predicted Price (10 seconds later): 18358222.77163377
# Signal: Buy | Time: 2024-03-29 05:47:58.893836
# Price after check: 70291.49
# Wrong prediction!
# Current Bitcoin Price: 70291.49
# Predicted Price (10 seconds later): -6467106.875032501
# Signal: Sell | Time: 2024-03-29 05:48:09.361282
# Price after check: 70291.43
# Correct prediction!
# Current Bitcoin Price: 70291.43
# Predicted Price (10 seconds later): 13052684.918477973
# Signal: Buy | Time: 2024-03-29 05:48:19.797027
# Price after check: 70291.05
# Wrong prediction!
# Current Bitcoin Price: 70291.05
# Predicted Price (10 seconds later): -13842075.584458226
# Signal: Sell | Time: 2024-03-29 05:48:30.228784
# Price after check: 70291.06
# Wrong prediction!
# Current Bitcoin Price: 70291.06
# Predicted Price (10 seconds later): -2660842.25637838
# Signal: Sell | Time: 2024-03-29 05:48:40.724791
# Price after check: 70291.11
# Wrong prediction!
# Current Bitcoin Price: 70291.11
# Predicted Price (10 seconds later): 30591322.716475975
# Signal: Buy | Time: 2024-03-29 05:48:51.154698
# Price after check: 70292.3
# Correct prediction!
# Current Bitcoin Price: 70292.3
# Predicted Price (10 seconds later): -4101461.378490912
# Signal: Sell | Time: 2024-03-29 05:49:01.607674
# Price after check: 70292.3
# Wrong prediction!
# The prediction: Correct prediction  3 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -11375030.524845563 | Signal: Sell | Time: 2024-03-29 05:49:11.862417
# Current Bitcoin Price: 70292.3
# Predicted Price (10 seconds later): 489152.4642312168
# Signal: Buy | Time: 2024-03-29 05:49:12.112822
# Price after check: 70293.41
# Correct prediction!
# Current Bitcoin Price: 70293.41
# Predicted Price (10 seconds later): 5941154.434907486
# Signal: Buy | Time: 2024-03-29 05:49:22.569073
# Price after check: 70293.2
# Wrong prediction!
# Current Bitcoin Price: 70293.2
# Predicted Price (10 seconds later): -60982266.500701606
# Signal: Sell | Time: 2024-03-29 05:49:33.015130
# Price after check: 70294.5
# Wrong prediction!
# Current Bitcoin Price: 70294.5
# Predicted Price (10 seconds later): -3287511.8793728957
# Signal: Sell | Time: 2024-03-29 05:49:43.504662
# Price after check: 70294.5
# Wrong prediction!
# Current Bitcoin Price: 70294.5
# Predicted Price (10 seconds later): -40404980.11075295
# Signal: Sell | Time: 2024-03-29 05:49:54.009398
# Price after check: 70294.5
# Wrong prediction!
# Current Bitcoin Price: 70294.5
# Predicted Price (10 seconds later): -16841497.21016733
# Signal: Sell | Time: 2024-03-29 05:50:04.452206
# Price after check: 70294.5
# Wrong prediction!
# The prediction: Correct prediction  1 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 462369.7766331754 | Signal: Buy | Time: 2024-03-29 05:50:14.720182
# Current Bitcoin Price: 70294.5
# Predicted Price (10 seconds later): 3347539.0582973496
# Signal: Buy | Time: 2024-03-29 05:50:14.951161
# Price after check: 70294.32
# Wrong prediction!
# Current Bitcoin Price: 70294.32
# Predicted Price (10 seconds later): 7265881.57895737
# Signal: Buy | Time: 2024-03-29 05:50:25.392875
# Price after check: 70294.2
# Wrong prediction!
# Current Bitcoin Price: 70294.2
# Predicted Price (10 seconds later): 40620719.345692046
# Signal: Buy | Time: 2024-03-29 05:50:35.835148
# Price after check: 70293.47
# Wrong prediction!
# Current Bitcoin Price: 70293.47
# Predicted Price (10 seconds later): -4963901.954937574
# Signal: Sell | Time: 2024-03-29 05:50:46.321680
# Price after check: 70293.33
# Correct prediction!
# Current Bitcoin Price: 70293.33
# Predicted Price (10 seconds later): -4814819.4483901365
# Signal: Sell | Time: 2024-03-29 05:50:56.783576
# Price after check: 70293.23
# Correct prediction!
# Current Bitcoin Price: 70293.23
# Predicted Price (10 seconds later): -42470554.037009396
# Signal: Sell | Time: 2024-03-29 05:51:07.210709
# Price after check: 70292.12
# Correct prediction!
# Current Bitcoin Price: 70292.12
# Predicted Price (10 seconds later): -82682823.75651734
# Signal: Sell | Time: 2024-03-29 05:51:17.653622
# Price after check: 70292.05
# Correct prediction!
# Current Bitcoin Price: 70292.05
# Predicted Price (10 seconds later): 30197332.82877328
# Signal: Buy | Time: 2024-03-29 05:51:28.097052
# Price after check: 70291.42
# Wrong prediction!
# Current Bitcoin Price: 70291.42
# Predicted Price (10 seconds later): -9297248.03325097
# Signal: Sell | Time: 2024-03-29 05:51:38.545563
# Price after check: 70291.42
# Wrong prediction!
# The prediction: Correct prediction  4 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 4785714.820196384 | Signal: Buy | Time: 2024-03-29 05:51:48.858789
# Current Bitcoin Price: 70291.42
# Predicted Price (10 seconds later): 3086056.980655176
# Signal: Buy | Time: 2024-03-29 05:51:49.130578
# Price after check: 70291.62
# Correct prediction!
# Current Bitcoin Price: 70291.62
# Predicted Price (10 seconds later): 16796395.43921719
# Signal: Buy | Time: 2024-03-29 05:51:59.562859
# Price after check: 70291.62
# Wrong prediction!
# Current Bitcoin Price: 70291.62
# Predicted Price (10 seconds later): 8476611.831204291
# Signal: Buy | Time: 2024-03-29 05:52:09.984404
# Price after check: 70290.29
# Wrong prediction!
# Current Bitcoin Price: 70290.29
# Predicted Price (10 seconds later): -2389942.8403105317
# Signal: Sell | Time: 2024-03-29 05:52:20.453663
# Price after check: 70290.3
# Wrong prediction!
# Current Bitcoin Price: 70290.3
# Predicted Price (10 seconds later): -4260086.0216812305
# Signal: Sell | Time: 2024-03-29 05:52:30.890161
# Price after check: 70290.75
# Wrong prediction!
# Current Bitcoin Price: 70290.75
# Predicted Price (10 seconds later): 74272428.66450742
# Signal: Buy | Time: 2024-03-29 05:52:41.319784
# Price after check: 70287.31
# Wrong prediction!
# The prediction: Correct prediction  1 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -4178970.1752701965 | Signal: Sell | Time: 2024-03-29 05:52:51.577602
# Current Bitcoin Price: 70287.31
# Predicted Price (10 seconds later): -5168873.685804936
# Signal: Sell | Time: 2024-03-29 05:52:51.814801
# Price after check: 70286.07
# Correct prediction!
# Current Bitcoin Price: 70286.07
# Predicted Price (10 seconds later): -9119023.332362326
# Signal: Sell | Time: 2024-03-29 05:53:02.349729
# Price after check: 70286.07
# Wrong prediction!
# Current Bitcoin Price: 70286.07
# Predicted Price (10 seconds later): 13193144.93805503
# Signal: Buy | Time: 2024-03-29 05:53:12.775973
# Price after check: 70286.79
# Correct prediction!
# Current Bitcoin Price: 70286.79
# Predicted Price (10 seconds later): -30662685.624448318
# Signal: Sell | Time: 2024-03-29 05:53:23.218559
# Price after check: 70286.79
# Wrong prediction!
# Current Bitcoin Price: 70286.79
# Predicted Price (10 seconds later): 18427704.067035843
# Signal: Buy | Time: 2024-03-29 05:53:33.657581
# Price after check: 70287.16
# Correct prediction!
# Current Bitcoin Price: 70287.16
# Predicted Price (10 seconds later): -6435080.38878637
# Signal: Sell | Time: 2024-03-29 05:53:44.107729
# Price after check: 70286.85
# Correct prediction!
# Current Bitcoin Price: 70286.85
# Predicted Price (10 seconds later): 33276381.452555902
# Signal: Buy | Time: 2024-03-29 05:53:54.604735
# Price after check: 70287.38
# Correct prediction!
# Current Bitcoin Price: 70287.38
# Predicted Price (10 seconds later): 7456821.224250457
# Signal: Buy | Time: 2024-03-29 05:54:05.156337
# Price after check: 70286.79
# Wrong prediction!
# Current Bitcoin Price: 70286.79
# Predicted Price (10 seconds later): -281134.0007451068
# Signal: Sell | Time: 2024-03-29 05:54:15.596334
# Price after check: 70285.82
# Correct prediction!
# Current Bitcoin Price: 70285.82
# Predicted Price (10 seconds later): -50531054.98166895
# Signal: Sell | Time: 2024-03-29 05:54:26.050672
# Price after check: 70286.07
# Wrong prediction!
#
# Enough correct predictions in the recent past. Continuing with prediction...
#
# Current Bitcoin Price: 70286.07
# Predicted Price (10 seconds later): -28301353.986827258
# Signal: Sell | Time: 2024-03-29 05:54:36.484986
# Price after check: 70286.08
# Wrong prediction!
# Current Bitcoin Price: 70286.08
# Predicted Price (10 seconds later): -12177143.853462141
# Signal: Sell | Time: 2024-03-29 05:54:46.934943
# Price after check: 70290.75
# Wrong prediction!
# Current Bitcoin Price: 70290.75
# Predicted Price (10 seconds later): -18957607.306981713
# Signal: Sell | Time: 2024-03-29 05:54:57.391886
# Price after check: 70290.91
# Wrong prediction!
# Current Bitcoin Price: 70290.91
# Predicted Price (10 seconds later): -40176495.69700558
# Signal: Sell | Time: 2024-03-29 05:55:07.836705
# Price after check: 70290.91
# Wrong prediction!
# Current Bitcoin Price: 70290.91
# Predicted Price (10 seconds later): -7243821.990542982
# Signal: Sell | Time: 2024-03-29 05:55:18.266950
# Price after check: 70290.96
# Wrong prediction!
# The prediction: Correct prediction  0 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -10718029.658206072 | Signal: Sell | Time: 2024-03-29 05:55:28.529131
# Current Bitcoin Price: 70290.96
# Predicted Price (10 seconds later): -10049074.98866785
# Signal: Sell | Time: 2024-03-29 05:55:28.782193
# Price after check: 70290.86
# Correct prediction!
# Current Bitcoin Price: 70290.86
# Predicted Price (10 seconds later): -2228213.197379624
# Signal: Sell | Time: 2024-03-29 05:55:39.224754
# Price after check: 70290.88
# Wrong prediction!
# Current Bitcoin Price: 70290.88
# Predicted Price (10 seconds later): 28094962.584512055
# Signal: Buy | Time: 2024-03-29 05:55:49.652608
# Price after check: 70290.88
# Wrong prediction!
# Current Bitcoin Price: 70290.88
# Predicted Price (10 seconds later): -9516968.383541185
# Signal: Sell | Time: 2024-03-29 05:56:00.103053
# Price after check: 70290.1
# Correct prediction!
# Current Bitcoin Price: 70290.1
# Predicted Price (10 seconds later): -6548488.638045225
# Signal: Sell | Time: 2024-03-29 05:56:10.601838
# Price after check: 70287.8
# Correct prediction!
# Current Bitcoin Price: 70287.8
# Predicted Price (10 seconds later): 10365429.109874643
# Signal: Buy | Time: 2024-03-29 05:56:21.149568
# Price after check: 70274.11
# Wrong prediction!
# Current Bitcoin Price: 70274.11
# Predicted Price (10 seconds later): 7180992.549443797
# Signal: Buy | Time: 2024-03-29 05:56:31.608277
# Price after check: 70274.11
# Wrong prediction!
# Current Bitcoin Price: 70274.11
# Predicted Price (10 seconds later): 29135836.78371179
# Signal: Buy | Time: 2024-03-29 05:56:42.039254
# Price after check: 70274.05
# Wrong prediction!
# The prediction: Correct prediction  3 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -2831171.612549542 | Signal: Sell | Time: 2024-03-29 05:56:52.289349
# Current Bitcoin Price: 70274.05
# Predicted Price (10 seconds later): -33335325.520212583
# Signal: Sell | Time: 2024-03-29 05:56:52.503557
# Price after check: 70274.06
# Wrong prediction!
# Current Bitcoin Price: 70274.06
# Predicted Price (10 seconds later): 43627703.0204391
# Signal: Buy | Time: 2024-03-29 05:57:02.957704
# Price after check: 70274.06
# Wrong prediction!
# Current Bitcoin Price: 70274.06
# Predicted Price (10 seconds later): -4356031.422659293
# Signal: Sell | Time: 2024-03-29 05:57:13.396719
# Price after check: 70273.0
# Correct prediction!
# Current Bitcoin Price: 70273.0
# Predicted Price (10 seconds later): 10848014.640791874
# Signal: Buy | Time: 2024-03-29 05:57:23.835421
# Price after check: 70272.99
# Wrong prediction!
# Current Bitcoin Price: 70272.99
# Predicted Price (10 seconds later): -15762523.523257993
# Signal: Sell | Time: 2024-03-29 05:57:34.304762
# Price after check: 70273.27
# Wrong prediction!
# Current Bitcoin Price: 70273.27
# Predicted Price (10 seconds later): 37741889.65208859
# Signal: Buy | Time: 2024-03-29 05:57:44.744598
# Price after check: 70273.32
# Correct prediction!
# Current Bitcoin Price: 70273.32
# Predicted Price (10 seconds later): -25004457.853414
# ...
# Signal: Sell | Time: 2024-03-29 06:41:11.454684
# Price after check: 70437.06
# Wrong prediction!
# Current Bitcoin Price: 70437.06
# Predicted Price (10 seconds later): -7913737.557040674
# Signal: Sell | Time: 2024-03-29 06:41:21.893028
# Price after check: 70433.45
# Correct prediction!
# Current Bitcoin Price: 70433.45
# Predicted Price (10 seconds later): 1494419.0456543437
# Signal: Buy | Time: 2024-03-29 06:41:32.393223
# Price after check: 70433.51
# Correct prediction!
# Current Bitcoin Price: 70433.51
# Predicted Price (10 seconds later): 7302679.724833054
# Signal: Buy | Time: 2024-03-29 06:41:43.013243
# Price after check: 70433.51
# Wrong prediction!
# Current Bitcoin Price: 70433.51
# Predicted Price (10 seconds later): -33684819.570741795
# Signal: Sell | Time: 2024-03-29 06:41:53.456481
# Price after check: 70433.51
# Wrong prediction!
# Current Bitcoin Price: 70433.51
# Predicted Price (10 seconds later): 102698188.95696849
# Signal: Buy | Time: 2024-03-29 06:42:03.906590
# Price after check: 70433.56
# Correct prediction!
# Current Bitcoin Price: 70433.56
# Predicted Price (10 seconds later): -1764346.640362201
# Signal: Sell | Time: 2024-03-29 06:42:14.386759
# Price after check: 70433.37
# Correct prediction!
# Current Bitcoin Price: 70433.37
# Predicted Price (10 seconds later): -16813974.07536496
# Signal: Sell | Time: 2024-03-29 06:42:24.865095
# Price after check: 70433.37
# Wrong prediction!
# Current Bitcoin Price: 70433.37
# Predicted Price (10 seconds later): 30593385.11392241
# Signal: Buy | Time: 2024-03-29 06:42:35.300798
# Price after check: 70438.48
# Correct prediction!
# Current Bitcoin Price: 70438.48
# Predicted Price (10 seconds later): -279698.7852383618
# Signal: Sell | Time: 2024-03-29 06:42:45.773670
# Price after check: 70437.13
# Correct prediction!
#
# Enough correct predictions in the recent past. Continuing with prediction...
#
# Current Bitcoin Price: 70437.13
# Predicted Price (10 seconds later): 14652445.647866964
# Signal: Buy | Time: 2024-03-29 06:42:56.207719
# Price after check: 70437.13
# Wrong prediction!
# Current Bitcoin Price: 70437.13
# Predicted Price (10 seconds later): 21886958.840009503
# Signal: Buy | Time: 2024-03-29 06:43:06.755020
# Price after check: 70438.01
# Correct prediction!
# Current Bitcoin Price: 70438.01
# Predicted Price (10 seconds later): -34718498.78399068
# Signal: Sell | Time: 2024-03-29 06:43:17.261634
# Price after check: 70437.69
# Correct prediction!
# Current Bitcoin Price: 70437.69
# Predicted Price (10 seconds later): 7511986.3474140735
# Signal: Buy | Time: 2024-03-29 06:43:27.683190
# Price after check: 70437.55
# Wrong prediction!
# Current Bitcoin Price: 70437.55
# Predicted Price (10 seconds later): -18453019.27433437
# Signal: Sell | Time: 2024-03-29 06:43:38.117957
# Price after check: 70437.55
# Wrong prediction!
# Current Bitcoin Price: 70437.55
# Predicted Price (10 seconds later): 65011670.67614087
# Signal: Buy | Time: 2024-03-29 06:43:48.701243
# Price after check: 70437.55
# Wrong prediction!
# Current Bitcoin Price: 70437.55
# Predicted Price (10 seconds later): -27545859.665210545
# Signal: Sell | Time: 2024-03-29 06:43:59.214281
# Price after check: 70438.99
# Wrong prediction!
# The prediction: Correct prediction  2 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 16262106.406807572 | Signal: Buy | Time: 2024-03-29 06:44:09.456139
# Current Bitcoin Price: 70438.99
# Predicted Price (10 seconds later): -1354048.9670978296
# Signal: Sell | Time: 2024-03-29 06:44:09.687042
# Price after check: 70439.4
# Wrong prediction!
# Current Bitcoin Price: 70439.4
# Predicted Price (10 seconds later): 25144311.695631668
# Signal: Buy | Time: 2024-03-29 06:44:20.147502
# Price after check: 70439.45
# Correct prediction!
# Current Bitcoin Price: 70439.45
# Predicted Price (10 seconds later): 4054529.335580427
# Signal: Buy | Time: 2024-03-29 06:44:30.594744
# Price after check: 70439.45
# Wrong prediction!
# Current Bitcoin Price: 70439.45
# Predicted Price (10 seconds later): -1835202.5920653224
# Signal: Sell | Time: 2024-03-29 06:44:41.029982
# Price after check: 70439.53
# Wrong prediction!
# Current Bitcoin Price: 70439.53
# Predicted Price (10 seconds later): -63918081.667001225
# Signal: Sell | Time: 2024-03-29 06:44:51.538166
# Price after check: 70439.92
# Wrong prediction!
# Current Bitcoin Price: 70439.92
# Predicted Price (10 seconds later): -40124481.87002613
# Signal: Sell | Time: 2024-03-29 06:45:01.975430
# Price after check: 70440.84
# Wrong prediction!
# The prediction: Correct prediction  1 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -6472244.610680431 | Signal: Sell | Time: 2024-03-29 06:45:12.218735
# Current Bitcoin Price: 70440.84
# Predicted Price (10 seconds later): -3845442.7949802293
# Signal: Sell | Time: 2024-03-29 06:45:12.470847
# Price after check: 70440.69
# Correct prediction!
# Current Bitcoin Price: 70440.69
# Predicted Price (10 seconds later): -19213883.186878346
# Signal: Sell | Time: 2024-03-29 06:45:22.918419
# Price after check: 70441.01
# Wrong prediction!
# Current Bitcoin Price: 70441.01
# Predicted Price (10 seconds later): 14336101.364121724
# Signal: Buy | Time: 2024-03-29 06:45:33.359224
# Price after check: 70463.36
# Correct prediction!
# Current Bitcoin Price: 70463.36
# Predicted Price (10 seconds later): 2392485.702195319
# Signal: Buy | Time: 2024-03-29 06:45:43.828292
# Price after check: 70463.36
# Wrong prediction!
# Current Bitcoin Price: 70463.36
# Predicted Price (10 seconds later): 6826184.920974831
# Signal: Buy | Time: 2024-03-29 06:45:54.298076
# Price after check: 70463.86
# Correct prediction!
# Current Bitcoin Price: 70463.86
# Predicted Price (10 seconds later): 2914691.731282767
# Signal: Buy | Time: 2024-03-29 06:46:04.819604
# Price after check: 70463.53
# Wrong prediction!
# Current Bitcoin Price: 70463.53
# Predicted Price (10 seconds later): 72841530.03266215
# Signal: Buy | Time: 2024-03-29 06:46:15.289364
# Price after check: 70465.12
# Correct prediction!
# Current Bitcoin Price: 70465.12
# Predicted Price (10 seconds later): 7808868.1019507265
# Signal: Buy | Time: 2024-03-29 06:46:25.732113
# Price after check: 70453.37
# Wrong prediction!
# Current Bitcoin Price: 70453.37
# Predicted Price (10 seconds later): 7556800.8899618
# Signal: Buy | Time: 2024-03-29 06:46:36.185018
# Price after check: 70453.37
# Wrong prediction!
# The prediction: Correct prediction  4 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 17578509.661278684 | Signal: Buy | Time: 2024-03-29 06:46:46.418131
# Current Bitcoin Price: 70453.37
# Predicted Price (10 seconds later): -1935131.8792974828
# Signal: Sell | Time: 2024-03-29 06:46:46.645842
# Price after check: 70453.81
# Wrong prediction!
# Current Bitcoin Price: 70453.81
# Predicted Price (10 seconds later): 26282773.82820513
# Signal: Buy | Time: 2024-03-29 06:46:57.089327
# Price after check: 70453.81
# Wrong prediction!
# Current Bitcoin Price: 70453.81
# Predicted Price (10 seconds later): 12437221.294337545
# Signal: Buy | Time: 2024-03-29 06:47:07.522345
# Price after check: 70453.05
# Wrong prediction!
# Current Bitcoin Price: 70453.05
# Predicted Price (10 seconds later): 23438479.8556184
# Signal: Buy | Time: 2024-03-29 06:47:17.954431
# Price after check: 70453.5
# Correct prediction!
# Current Bitcoin Price: 70453.5
# Predicted Price (10 seconds later): -5324439.456876227
# Signal: Sell | Time: 2024-03-29 06:47:28.424698
# Price after check: 70453.61
# Wrong prediction!
# Current Bitcoin Price: 70453.61
# Predicted Price (10 seconds later): 12125462.046373852
# Signal: Buy | Time: 2024-03-29 06:47:38.846401
# Price after check: 70453.61
# Wrong prediction!
# The prediction: Correct prediction  1 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 10589172.84719602 | Signal: Buy | Time: 2024-03-29 06:47:49.185676
# Current Bitcoin Price: 70453.61
# Predicted Price (10 seconds later): -26643579.280952476
# Signal: Sell | Time: 2024-03-29 06:47:49.398952
# Price after check: 70453.61
# Wrong prediction!
# Current Bitcoin Price: 70453.61
# Predicted Price (10 seconds later): 17417830.01678222
# Signal: Buy | Time: 2024-03-29 06:47:59.850173
# Price after check: 70453.61
# Wrong prediction!
# Current Bitcoin Price: 70453.61
# Predicted Price (10 seconds later): 4270468.621837738
# Signal: Buy | Time: 2024-03-29 06:48:10.259612
# Price after check: 70452.44
# Wrong prediction!
# Current Bitcoin Price: 70452.44
# Predicted Price (10 seconds later): -2719545.750900395
# Signal: Sell | Time: 2024-03-29 06:48:20.787693
# Price after check: 70451.84
# Correct prediction!
# Current Bitcoin Price: 70451.84
# Predicted Price (10 seconds later): -27592044.22008627
# Signal: Sell | Time: 2024-03-29 06:48:31.265213
# Price after check: 70450.51
# Correct prediction!
# Current Bitcoin Price: 70450.51
# Predicted Price (10 seconds later): 3031104.3164195903
# Signal: Buy | Time: 2024-03-29 06:48:41.698050
# Price after check: 70449.96
# Wrong prediction!
# Current Bitcoin Price: 70449.96
# Predicted Price (10 seconds later): 28717910.31628081
# Signal: Buy | Time: 2024-03-29 06:48:52.143735
# Price after check: 70449.91
# Wrong prediction!
# The prediction: Correct prediction  2 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 1507883.9192254732 | Signal: Buy | Time: 2024-03-29 06:49:02.445679
# Current Bitcoin Price: 70449.91
# Predicted Price (10 seconds later): 11082403.628000025
# Signal: Buy | Time: 2024-03-29 06:49:02.672336
# Price after check: 70449.86
# Wrong prediction!
# Current Bitcoin Price: 70449.86
# Predicted Price (10 seconds later): 35002969.31295924
# Signal: Buy | Time: 2024-03-29 06:49:13.113491
# Price after check: 70449.39
# Wrong prediction!
# Current Bitcoin Price: 70449.39
# Predicted Price (10 seconds later): 6257542.068712504
# Signal: Buy | Time: 2024-03-29 06:49:23.551722
# Price after check: 70449.25
# Wrong prediction!
# Current Bitcoin Price: 70449.25
# Predicted Price (10 seconds later): -29431993.514483962
# Signal: Sell | Time: 2024-03-29 06:49:33.982954
# Price after check: 70450.06
# Wrong prediction!
# Current Bitcoin Price: 70450.06
# Predicted Price (10 seconds later): 39410452.116169535
# Signal: Buy | Time: 2024-03-29 06:49:44.477239
# Price after check: 70450.66
# Correct prediction!
# Current Bitcoin Price: 70450.66
# Predicted Price (10 seconds later): 1917790.927286782
# Signal: Buy | Time: 2024-03-29 06:49:54.938904
# Price after check: 70450.66
# Wrong prediction!
# The prediction: Correct prediction  1 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 4211425.701579976 | Signal: Buy | Time: 2024-03-29 06:50:05.197995
# Current Bitcoin Price: 70450.66
# Predicted Price (10 seconds later): -23911535.261481963
# Signal: Sell | Time: 2024-03-29 06:50:05.419749
# Price after check: 70450.1
# Correct prediction!
# Current Bitcoin Price: 70450.1
# Predicted Price (10 seconds later): 5694370.733691569
# Signal: Buy | Time: 2024-03-29 06:50:15.855987
# Price after check: 70459.1
# Correct prediction!
# Current Bitcoin Price: 70459.1
# Predicted Price (10 seconds later): -4463778.080769266
# Signal: Sell | Time: 2024-03-29 06:50:26.368703
# Price after check: 70459.09
# Correct prediction!
# Current Bitcoin Price: 70459.09
# Predicted Price (10 seconds later): 16962986.36430847
# Signal: Buy | Time: 2024-03-29 06:50:36.903693
# Price after check: 70459.09
# Wrong prediction!
# Current Bitcoin Price: 70459.09
# Predicted Price (10 seconds later): 5476350.969887979
# Signal: Buy | Time: 2024-03-29 06:50:47.350222
# Price after check: 70459.16
# Correct prediction!
# Current Bitcoin Price: 70459.16
# Predicted Price (10 seconds later): 14562010.192054305
# Signal: Buy | Time: 2024-03-29 06:50:57.812788
# Price after check: 70459.75
# Correct prediction!
# Current Bitcoin Price: 70459.75
# Predicted Price (10 seconds later): -12539381.092809187
# Signal: Sell | Time: 2024-03-29 06:51:08.254432
# Price after check: 70459.33
# Correct prediction!
# Current Bitcoin Price: 70459.33
# Predicted Price (10 seconds later): 7148100.692157498
# Signal: Buy | Time: 2024-03-29 06:51:18.699473
# Price after check: 70459.15
# Wrong prediction!
# Current Bitcoin Price: 70459.15
# Predicted Price (10 seconds later): 8291439.598412705
# Signal: Buy | Time: 2024-03-29 06:51:29.149322
# Price after check: 70459.16
# Correct prediction!
# Current Bitcoin Price: 70459.16
# Predicted Price (10 seconds later): -31061345.428431466
# Signal: Sell | Time: 2024-03-29 06:51:39.593257
# Price after check: 70459.16
# Wrong prediction!
#
# Enough correct predictions in the recent past. Continuing with prediction...
#
# Current Bitcoin Price: 70459.16
# Predicted Price (10 seconds later): -5360382.165531484
# Signal: Sell | Time: 2024-03-29 06:51:50.029561
# Price after check: 70459.16
# Wrong prediction!
# Current Bitcoin Price: 70459.16
# Predicted Price (10 seconds later): -24529279.498880863
# Signal: Sell | Time: 2024-03-29 06:52:00.465846
# Price after check: 70459.16
# Wrong prediction!
# Current Bitcoin Price: 70459.16
# Predicted Price (10 seconds later): 28500324.496889334
# Signal: Buy | Time: 2024-03-29 06:52:10.938619
# Price after check: 70459.36
# Correct prediction!
# Current Bitcoin Price: 70459.36
# Predicted Price (10 seconds later): 6966812.97441501
# Signal: Buy | Time: 2024-03-29 06:52:21.388639
# Price after check: 70459.38
# Correct prediction!
# Current Bitcoin Price: 70459.38
# Predicted Price (10 seconds later): -17022058.331318744
# Signal: Sell | Time: 2024-03-29 06:52:31.813033
# Price after check: 70459.38
# Wrong prediction!
# Current Bitcoin Price: 70459.38
# Predicted Price (10 seconds later): 12322405.818057183
# Signal: Buy | Time: 2024-03-29 06:52:42.371912
# Price after check: 70459.38
# Wrong prediction!
# Current Bitcoin Price: 70459.38
# Predicted Price (10 seconds later): -2401930.5431373264
# Signal: Sell | Time: 2024-03-29 06:52:52.852139
# Price after check: 70460.01
# Wrong prediction!
# The prediction: Correct prediction  2 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: 28546987.194726996 | Signal: Buy | Time: 2024-03-29 06:53:03.083334
# Current Bitcoin Price: 70460.01
# Predicted Price (10 seconds later): 13516918.741154261
# Signal: Buy | Time: 2024-03-29 06:53:03.311293
# Price after check: 70460.01
# Wrong prediction!
# Current Bitcoin Price: 70460.01
# Predicted Price (10 seconds later): -50872238.287351236
# Signal: Sell | Time: 2024-03-29 06:53:13.800965
# Price after check: 70460.22
# Wrong prediction!
# Current Bitcoin Price: 70460.22
# Predicted Price (10 seconds later): -7127646.0105589675
# Signal: Sell | Time: 2024-03-29 06:53:24.233575
# Price after check: 70464.15
# Wrong prediction!
# Current Bitcoin Price: 70464.15
# Predicted Price (10 seconds later): 54350787.87985987
# Signal: Buy | Time: 2024-03-29 06:53:34.666741
# Price after check: 70464.15
# Wrong prediction!
# Current Bitcoin Price: 70464.15
# Predicted Price (10 seconds later): 7904443.975055809
# Signal: Buy | Time: 2024-03-29 06:53:45.160596
# Price after check: 70464.63
# Correct prediction!
# Current Bitcoin Price: 70464.63
# Predicted Price (10 seconds later): 4703362.907775939
# Signal: Buy | Time: 2024-03-29 06:53:55.587768
# Price after check: 70464.63
# Wrong prediction!
# The prediction: Correct prediction  1 Wrong prediction  5
#
# Retraining the model with updated data...
#
# New Prediction: | Predicted Price: -21531045.60262454 | Signal: Sell | Time: 2024-03-29 06:54:05.805649
# Current Bitcoin Price: 70464.63
# Predicted Price (10 seconds later): -7295697.563307362
# Signal: Sell | Time: 2024-03-29 06:54:06.045245
# Price after check: 70465.95
# Wrong prediction!
# Current Bitcoin Price: 70465.95
# Predicted Price (10 seconds later): -4530364.485933901
# Signal: Sell | Time: 2024-03-29 06:54:16.504526
# Price after check: 70465.07
# Correct prediction!
# Current Bitcoin Price: 70465.07
# Predicted Price (10 seconds later): 9429972.264769465
# Signal: Buy | Time: 2024-03-29 06:54:26.934631
# Price after check: 70464.47
# Wrong prediction!
# Current Bitcoin Price: 70464.47
# Predicted Price (10 seconds later): 6538553.074493214
# Signal: Buy | Time: 2024-03-29 06:54:37.360158
# Price after check: 70464.47
# Wrong prediction!
# Current Bitcoin Price: 70464.47
# Predicted Price (10 seconds later): 4513836.9603478145
# Signal: Buy | Time: 2024-03-29 06:54:47.822616
